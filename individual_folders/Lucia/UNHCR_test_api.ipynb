# %% [markdown]
# # Test UNCHR API

# %%
curl -s: "https://api.unhcr.org/population/v1/population/?year=2022&format=json" | jq
# Out:
# {
#   "page": 1,
#   "short-url": "P11WXn",
#   "maxPages": 1,
#   "total": [],
#   "items": [
#     {
#       "year": 2022,
#       "coo_id": "-",
#       "coo_name": "-",
#       "coo": "-",
#       "coo_iso": "-",
#       "coa_id": "-",
#       "coa_name": "-",
#       "coa": "-",
#       "coa_iso": "-",
#       "refugees": 29429078,
#       "asylum_seekers": 5442319,
#       "returned_refugees": 1356261,
#       "idps": 57321197,
#       "returned_idps": 8324166,
#       "stateless": 4428314,
#       "ooc": 6008804,
#       "oip": 5217456,
#       "hst": 23957770
#     }
#   ]
# }

# %%
curl -s: "https://api.unhcr.org/population/v1/population/?country_codes:BRA,CHL,ARG,CHL,PER,IND,NGA,KEN,ZMB&format=json" | jq
# Out:
# {
#   "page": 1,
#   "short-url": "8a7RaT",
#   "maxPages": 1,
#   "total": [],
#   "items": [
#     {
#       "year": 1951,
#       "coo_id": "-",
#       "coo_name": "-",
#       "coo": "-",
#       "coo_iso": "-",
#       "coa_id": "-",
#       "coa_name": "-",
#       "coa": "-",
#       "coa_iso": "-",
#       "refugees": 2116011,
#       "asylum_seekers": "0",
#       "returned_refugees": "0",
#       "idps": "0",
#       "returned_idps": "0",
#       "stateless": "0",
#       "ooc": "0",
#       "oip": "-",
#       "hst": "-"
#     },
#     {
#       "year": 1952,
#       "coo_id": "-",
#       "coo_name": "-",
#       "coo": "-",
#       "coo_iso": "-",
#       "coa_id": "-",
#       "coa_name": "-",
#       "coa": "-",
#       "coa_iso": "-",
#       "refugees": 1952928,
#       "asylum_seekers": "0",
#       "returned_refugees": "0",
#       "idps": "0",
#       "returned_idps": "0",
#       "stateless": "0",
#       "ooc": "0",
#       "oip": "-",
#       "hst": "-"
# ...
