# %%
echo "Latitude,Longitude,AddressType,Name" > KenyaGeo.csv

while IFS= read -r line
do
    encoded_query=$(echo "$line" | jq -sRr @uri)
    response=$(curl -s "https://nominatim.openstreetmap.org/search?q=${encoded_query}&format=json")
    echo "$response" | jq -r '.[] | [.lat, .lon, .addresstype, .name] | @csv' >> KenyaGeo.csv
    sleep 1  # Delay to respect API rate limit
done < KenyaCityCensus.csv

# %%
echo "Latitude,Longitude,AddressType,Name" > MarsabitGeo.csv

while IFS= read -r line
do
    encoded_query=$(echo "$line" | jq -sRr @uri)
    response=$(curl -s "https://nominatim.openstreetmap.org/search?q=${encoded_query}&format=json")
    echo "$response" | jq -r '.[] | [.lat, .lon, .addresstype, .name] |join(",")' >> MarsabitGeo.csv
    sleep 1  # Delay to respect API rate limit
done < Marsabit.csv

# %%
while IFS= read -r line
do
    encoded_query=$(echo "$line" | jq -sRr @uri)
    response=$(curl -s "https://nominatim.openstreetmap.org/search?q=${encoded_query}&format=json")
    echo "$response" | jq 
    sleep 1  # Delay to respect API rate limit
done < Marsabit.csv
# Out:
# [
#   {
#     "place_id": 103355927,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "node",
#     "osm_id": 1802169356,
#     "lat": "49.6124294",
#     "lon": "6.1305758",
#     "class": "shop",
#     "type": "clothes",
#     "place_rank": 30,
#     "importance": 9.99999999995449e-06,
#     "addresstype": "shop",
#     "name": "Country",
#     "display_name": "Country, Centre Neuberg, Ville-Haute, Luxembourg, Canton Luxembourg, 1660, Lëtzebuerg",
#     "boundingbox": [
#       "49.6123794",
#       "49.6124794",
#       "6.1305258",
#       "6.1306258"
#     ]
#   },
#   {
#     "place_id": 103243827,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "node",
#     "osm_id": 2130812364,
#     "lat": "49.600686",
#     "lon": "6.1306078",
#     "class": "amenity",
#     "type": "fast_food",
#     "place_rank": 30,
#     "importance": 9.99999999995449e-06,
#     "addresstype": "amenity",
#     "name": "Country",
#     "display_name": "Country, Rue Joseph Junck, Gare, Luxembourg, Canton Luxembourg, 1839, Lëtzebuerg",
#     "boundingbox": [
#       "49.6006360",
#       "49.6007360",
#       "6.1305578",
#       "6.1306578"
#     ]
#   },
#   {
#     "place_id": 253277713,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "node",
#     "osm_id": 4758027893,
#     "lat": "43.2616855",
#     "lon": "-2.937186",
#     "class": "office",
#     "type": "estate_agent",
#     "place_rank": 30,
#     "importance": 9.99999999995449e-06,
#     "addresstype": "office",
#     "name": "City",
#     "display_name": "City, Calle Iparraguirre / Iparraguirre kalea, Autonomia, Indautxu, Abando, Bilbao, Bizkaia, Euskadi, 48011, España",
#     "boundingbox": [
#       "43.2616355",
#       "43.2617355",
#       "-2.9372360",
#       "-2.9371360"
#     ]
#   }
# ]
# [
#   {
#     "place_id": 36159837,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15992553,
#     "lat": "3.1070301000000002",
#     "lon": "37.69527558861103",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 12,
#     "importance": 0.45000999999999997,
#     "addresstype": "county",
#     "name": "North Horr",
#     "display_name": "North Horr, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "1.7594475",
#       "4.4550652",
#       "36.1697836",
#       "38.9585066"
#     ]
#   },
#   {
#     "place_id": 36285678,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15998072,
#     "lat": "3.321682",
#     "lon": "37.070624",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 16,
#     "importance": 0.35000999999999993,
#     "addresstype": "village",
#     "name": "North Horr",
#     "display_name": "North Horr, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "2.9450702",
#       "3.8647184",
#       "36.2005466",
#       "37.2745500"
#     ]
#   }
# ]
# [
#   {
#     "place_id": 36196303,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15992562,
#     "lat": "2.37169725",
#     "lon": "37.94926999582403",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 12,
#     "importance": 0.45000999999999997,
#     "addresstype": "county",
#     "name": "Saku",
#     "display_name": "Saku, Marsabit, Eastern, 60500, Kenya",
#     "boundingbox": [
#       "2.1009196",
#       "2.6384933",
#       "37.7586737",
#       "38.1864518"
#     ]
#   }
# ]
# [
#   {
#     "place_id": 36373204,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15992535,
#     "lat": "2.86885305",
#     "lon": "38.83203237871054",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 12,
#     "importance": 0.45000999999999997,
#     "addresstype": "county",
#     "name": "Moyale",
#     "display_name": "Moyale, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "2.0951549",
#       "3.6542229",
#       "38.1298881",
#       "39.3465018"
#     ]
#   },
#   {
#     "place_id": 36318041,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "way",
#     "osm_id": 564383325,
#     "lat": "3.51590545",
#     "lon": "39.05841842957835",
#     "class": "place",
#     "type": "town",
#     "place_rank": 18,
#     "importance": 0.38496254669333574,
#     "addresstype": "town",
#     "name": "Moyale",
#     "display_name": "Moyale, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "3.4954303",
#       "3.5368942",
#       "39.0404534",
#       "39.0842700"
#     ]
#   }
# ]
# [
#   {
#     "place_id": 369005326,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15992634,
#     "lat": "2.3437975",
#     "lon": "37.29645622481332",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 12,
#     "importance": 0.45000999999999997,
#     "addresstype": "county",
#     "name": "Laisamis",
#     "display_name": "Laisamis, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "1.2610344",
#       "3.4612621",
#       "36.2097189",
#       "38.3853202"
#     ]
#   },
#   {
#     "place_id": 369008917,
#     "licence": "Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright",
#     "osm_type": "relation",
#     "osm_id": 15998016,
#     "lat": "1.590479",
#     "lon": "37.802513",
#     "class": "boundary",
#     "type": "administrative",
#     "place_rank": 16,
#     "importance": 0.35000999999999993,
#     "addresstype": "town",
#     "name": "Laisamis",
#     "display_name": "Laisamis, Marsabit, Eastern, Kenya",
#     "boundingbox": [
#       "1.2610344",
#       "1.8621449",
#       "37.4495448",
#       "38.3853202"
#     ]
#   }
# ]

# %%
cat Kenyacities2.csv
# Out:
# City,Adm.,Population
# Athi River (Mavoko),EA,"81,302"
# Awendo,NY,"16,815"
# Banisa (Banissa),NE,"14,974"
# Bondo,NY,"22,712"
# Bungoma,WE,"68,031"
# Busia,WE,"71,886"
# Chuka,EA,"22,388"
# Elburgon,RV,"28,359"
# Eldama Ravine,RV,"21,385"
# Eldoret,RV,"475,716"
# Elwak,NE,"60,732"
# Emali,EA,"18,325"
# Embu,EA,"64,979"
# Garbatula,EA,"17,443"
# Garissa,NE,"163,399"
# Gilgil,RV,"60,711"
# Githunguri,EA,"63,319"
# Habaswein,NE,"49,599"
# Hola,CO,"20,912"
# Homa Bay,NY,"44,949"
# Isebania,NY,"23,891"
# Isiolo,EA,"78,650"
# Juja,CE,"156,041"
# Kabarnet,RV,"22,474"
# Kajiado,RV,"24,678"
# Kakamega,WE,"107,227"
# Kakuma,RV,"22,984"
# Kapsabet,RV,"41,997"
# Karatina,CE,"23,552"
# Karuri,CE,"194,342"
# Kehancha,NY,"22,194"
# Kenol,CE,"44,086"
# Kericho,RV,"53,804"
# Kerugoya,CE,"30,045"
# Kiambu,CE,"147,870"
# Kikuyu,CE,"323,881"
# Kilifi,CO,"74,270"
# Kimilili,WE,"56,050"
# Kiminini,RV,"16,560"
# Kiserian,RV,"76,903"
# Kisii,NY,"112,417"
# Kisumu,NY,"397,957"
# Kitale,RV,"162,174"
# Kitengela,RV,"154,436"
# Kitui,EA,"29,062"
# Lafey,NE,"22,882"
# Lamu,CO,"25,385"
# Limuru,CE,"81,316"
# Lodwar,RV,"82,970"
# Machakos,EA,"63,767"
# Mai Mahiu,RV,"20,823"
# Mairo Inya,CE,"30,527"
# Makindu,EA,"15,038"
# Makutano (Kapenguria),RV,"28,469"
# Malaba,WE,"15,581"
# Malindi,CO,"119,859"
# Mandera,NE,"114,718"
# Maralal,RV,"31,350"
# Mariakani,CO,"31,715"
# Marsabit,EA,"36,289"
# Masalani,NE,"43,642"
# Maua,EA,"22,121"
# Mazeras,CO,"16,254"
# Mbale (Vihiga),WE,"17,404"
# Mbita (Mbita Point),NY,"14,916"
# Meru,EA,"80,191"
# Migori,NY,"71,668"
# Mlolongo,EA,"136,351"
# Moi's Bridge,WE,"16,355"
# Molo (Turi),RV,"48,356"
# Mombasa,CO,"1,208,333"
# Moyale,EA,"47,850"
# Msambweni,CO,"14,951"
# Mtwapa,CO,"90,677"
# Mumias,WE,"41,942"
# Murang'a,CE,"43,314"
# Mwingi,EA,"17,025"
# Nairobi,NA,"4,397,073"
# Naivasha,RV,"198,444"
# Nakuru,RV,"570,674"
# Namanga,RV,"14,922"
# Nanyuki,RV,"72,813"
# Narok,RV,"65,430"
# Ngong,RV,"102,323"
# Njoro,RV,"42,173"
# Nyahururu,RV,"37,650"
# Nyamira,NY,"24,483"
# Nyeri,CE,"80,081"
# Ongata Rongai,RV,"172,569"
# Oyugis,NY,"19,947"
# Rhamu,NE,"35,644"
# Rongo,NY,"20,688"
# Ruiru,CE,"490,120"
# Siaya,NY,"33,153"
# Takaba,NE,"21,517"
# Taveta,CO,"22,018"
# Thika,CE,"251,407"
# Ukunda,CO,"77,686"
# Voi,CO,"53,353"
# Wajir,NE,"90,116"
# Wanguru,CE,"51,722"
# Watamu,CO,"27,857"
# Webuye,WE,"42,642"
# Wote,EA,"19,725"

# %%
cleancity=$(cut -d, -f1 Kenyacities2.csv)
 

while read line 
    do
    echo "$line,Kenya"
    done <<< $cleancity > CitiesKenyaR.csv

# %%
sed -i "0,/Kenya/{s/Kenya/country/}" CitiesKenyaR.csv

# %%
echo "Latitude,Longitude,AddressType,Name" > CitiesKenyaRGeoCed.csv

while IFS= read -r line
do
    encoded_query=$(echo "$line" | jq -sRr @uri)
    response=$(curl -s "https://nominatim.openstreetmap.org/search?q=${encoded_query}&format=json")
    echo "$response" | jq -r '.[] | [.lat, .lon, .addresstype, .name] | @csv' >> CitiesKenyaRGeoCed.csv
    sleep 1  # Delay to respect API rate limit
done < CitiesKenyaR.csv
